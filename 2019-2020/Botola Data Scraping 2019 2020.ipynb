# %%
from selenium import webdriver
from bs4 import BeautifulSoup
import pandas as pd

final_standing_table=[]
links=['https://www.goalzz.com/main.aspx?c=17865&stage=1&smonth=201909','https://www.goalzz.com/main.aspx?c=17865&stage=1&smonth=201910','https://www.goalzz.com/main.aspx?c=17865&stage=1&smonth=201911','https://www.goalzz.com/main.aspx?c=17865&stage=1&smonth=201912','https://www.goalzz.com/main.aspx?c=17865&stage=1&smonth=202001','https://www.goalzz.com/main.aspx?c=17865&stage=1&smonth=202002','https://www.goalzz.com/main.aspx?c=17865&stage=1&smonth=202003','https://www.goalzz.com/main.aspx?c=17865&stage=1&smonth=202007','https://www.goalzz.com/main.aspx?c=17865&stage=1&smonth=202008','https://www.goalzz.com/main.aspx?c=17865&stage=1&smonth=202009','https://www.goalzz.com/main.aspx?c=17865&stage=1&smonth=202010']

for j in range(0,len(links)):
    driver = webdriver.Chrome()
    driver.get(links[j])

    html = driver.page_source 
    driver.quit() 



    soup=BeautifulSoup(html)
    standing_table=soup.select('tr[data-match],td.match_date')
    date_index=[]
    for i in range(0,len(standing_table)):
        if str(standing_table[i]).startswith('<td'):
            standing_table[i]=standing_table[i].text
            date_index.append(i)

    for i in range(0,len(standing_table)):
        if i not in date_index:
            standing_table[i]=[standing_table[i].find('span').text[:5],standing_table[i].find_all('a', class_='tl')[0].text,standing_table[i].find('td', class_='sc').text,standing_table[i].find_all('a', class_='tl')[1].text,standing_table[i].find('td', class_='s').text]

    for i in range(0,len(standing_table)):
        if i in date_index:
            a=i
        if i not in date_index:
            standing_table[i].append(standing_table[a])

    for index in sorted(date_index, reverse=True):
        del standing_table[index]
    
    final_standing_table += standing_table
    
final_standing_table[:5]
# Out:
# [['15:59',
#   'Olympique Club de Safi',
#   '1 : 1',
#   'Olympique Club De Khouribga',
#   'Week # 1',
#   'Saturday 14 September 2019'],
#  ['18:00',
#   'Moghreb Tetouan',
#   '2 : 0',
#   'FAR Rabat',
#   'Week # 1',
#   'Saturday 14 September 2019'],
#  ['20:00',
#   'Fath Union Sport de Rabat',
#   '1 : 0',
#   'Ittihad Tanger',
#   'Week # 1',
#   'Saturday 14 September 2019'],
#  ['17:03',
#   'Youssoufia Berrechid',
#   '1 : 2',
#   'Renaissance Zemamra',
#   'Week # 1',
#   'Sunday 15 September 2019'],
#  ['20:02',
#   'Rapide Oued Zem',
#   '0 : 0',
#   'Mouloudia Oujda',
#   'Week # 1',
#   'Sunday 15 September 2019']]

# %%
len(final_standing_table)
# Out:
# 240

# %%
df = pd.DataFrame(final_standing_table, columns =['Time', 'Receiving team', 'Score', 'Guest team', 'Week','Date'])
df
# Out:
#       Time               Receiving team  Score                   Guest team  \
# 0    15:59       Olympique Club de Safi  1 : 1  Olympique Club De Khouribga
# 1    18:00              Moghreb Tetouan  2 : 0                    FAR Rabat
# 2    20:00    Fath Union Sport de Rabat  1 : 0               Ittihad Tanger
# 3    17:03         Youssoufia Berrechid  1 : 2          Renaissance Zemamra
# 4    20:02              Rapide Oued Zem  0 : 0              Mouloudia Oujda
# ..     ...                          ...    ...                          ...
# 235  19:00          Renaissance Zemamra  1 : 1          Raja de Beni Mellal
# 236  19:00           Raja Club Athletic  2 : 1                    FAR Rabat
# 237  19:00  Hassania Union Sport Agadir  0 : 1              Mouloudia Oujda
# 238  19:00       Olympique Club de Safi  0 : 1       Renaissance de Berkane
# 239  19:00    Fath Union Sport de Rabat  1 : 2          Wydad Athletic Club
#
#           Week                        Date
# 0     Week # 1  Saturday 14 September 2019
# 1     Week # 1  Saturday 14 September 2019
# 2     Week # 1  Saturday 14 September 2019
# 3     Week # 1    Sunday 15 September 2019
# 4     Week # 1    Sunday 15 September 2019
# ..         ...                         ...
# 235  Week # 30    Saturday 10 October 2020
# 236  Week # 30      Sunday 11 October 2020
# 237  Week # 30      Sunday 11 October 2020
# 238  Week # 30      Sunday 11 October 2020
# 239  Week # 30      Sunday 11 October 2020
#
# [240 rows x 6 columns]

# %%
df.to_csv('Botola Data 2019 2020.csv')
