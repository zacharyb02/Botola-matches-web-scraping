# %%
from selenium import webdriver
from bs4 import BeautifulSoup
import pandas as pd

final_standing_table=[]
links=['https://www.goalzz.com/main.aspx?c=10392&stage=1&smonth=201509','https://www.goalzz.com/main.aspx?c=10392&stage=1&smonth=201510','https://www.goalzz.com/main.aspx?c=10392&stage=1&smonth=201511','https://www.goalzz.com/main.aspx?c=10392&stage=1&smonth=201512','https://www.goalzz.com/main.aspx?c=10392&stage=1&smonth=201601','https://www.goalzz.com/main.aspx?c=10392&stage=1&smonth=201602','https://www.goalzz.com/main.aspx?c=10392&stage=1&smonth=201603','https://www.goalzz.com/main.aspx?c=10392&stage=1&smonth=201604','https://www.goalzz.com/main.aspx?c=10392&stage=1&smonth=201605','https://www.goalzz.com/main.aspx?c=10392&stage=1&smonth=201606']

for j in range(0,len(links)):
    driver = webdriver.Chrome()
    driver.get(links[j])

    html = driver.page_source 
    driver.quit() 



    soup=BeautifulSoup(html)
    standing_table=soup.select('tr[data-match],td.match_date')
    date_index=[]
    for i in range(0,len(standing_table)):
        if str(standing_table[i]).startswith('<td'):
            standing_table[i]=standing_table[i].text
            date_index.append(i)

    for i in range(0,len(standing_table)):
        if i not in date_index:
            standing_table[i]=[standing_table[i].find('span').text[:5],standing_table[i].find_all('a', class_='tl')[0].text,standing_table[i].find('td', class_='sc').text,standing_table[i].find_all('a', class_='tl')[1].text,standing_table[i].find('td', class_='s').text]

    for i in range(0,len(standing_table)):
        if i in date_index:
            a=i
        if i not in date_index:
            standing_table[i].append(standing_table[a])

    for index in sorted(date_index, reverse=True):
        del standing_table[index]
    
    final_standing_table += standing_table
    
final_standing_table[:5]
# Out:
# [['18:33',
#   'Hassania Union Sport Agadir',
#   '2 : 1',
#   'Chabab Rif Al Hoceima',
#   'Week # 1',
#   'Saturday 5 September 2015'],
#  ['20:30',
#   'Ittihad Tanger',
#   '2 : 0',
#   'Maghreb de Fes',
#   'Week # 1',
#   'Saturday 5 September 2015'],
#  ['15:33',
#   'Kenitra AC',
#   '0 : 0',
#   'Difaa Hassani El Jadidi',
#   'Week # 1',
#   'Sunday 6 September 2015'],
#  ['16:02',
#   'Wydad Athletic Club',
#   '4 : 2',
#   'FAR Rabat',
#   'Week # 1',
#   'Sunday 6 September 2015'],
#  ['16:00',
#   'Fath Union Sport de Rabat',
#   '2 : 0',
#   'Raja Club Athletic',
#   'Week # 1',
#   'Sunday 6 September 2015']]

# %%
len(final_standing_table)
# Out:
# 240

# %%
df = pd.DataFrame(final_standing_table, columns =['Time', 'Receiving team', 'Score', 'Guest team', 'Week','Date'])
df
# Out:
#       Time               Receiving team  Score  \
# 0    18:33  Hassania Union Sport Agadir  2 : 1
# 1    20:30               Ittihad Tanger  2 : 0
# 2    15:33                   Kenitra AC  0 : 0
# 3    16:02          Wydad Athletic Club  4 : 2
# 4    16:00    Fath Union Sport de Rabat  2 : 0
# ..     ...                          ...    ...
# 235  16:59                   Kenitra AC  0 : 0
# 236  17:01       Olympique Club de Safi  1 : 0
# 237  17:01      Difaa Hassani El Jadidi  1 : 3
# 238  17:07       Renaissance de Berkane  2 : 1
# 239  17:00    Fath Union Sport de Rabat  4 : 2
#
#                          Guest team       Week                       Date
# 0             Chabab Rif Al Hoceima   Week # 1  Saturday 5 September 2015
# 1                    Maghreb de Fes   Week # 1  Saturday 5 September 2015
# 2           Difaa Hassani El Jadidi   Week # 1    Sunday 6 September 2015
# 3                         FAR Rabat   Week # 1    Sunday 6 September 2015
# 4                Raja Club Athletic   Week # 1    Sunday 6 September 2015
# ..                              ...        ...                        ...
# 235  Kawkab Athletic Club Marrakech  Week # 30       Saturday 4 June 2016
# 236           Chabab Rif Al Hoceima  Week # 30       Saturday 4 June 2016
# 237     Olympique Club De Khouribga  Week # 30       Saturday 4 June 2016
# 238                       FAR Rabat  Week # 30       Saturday 4 June 2016
# 239                 Mouloudia Oujda  Week # 30       Saturday 4 June 2016
#
# [240 rows x 6 columns]

# %%
df.to_csv('Botola Data 2015 2016.csv')
