# %%
from selenium import webdriver
from bs4 import BeautifulSoup
import pandas as pd

final_standing_table=[]
links=['https://www.goalzz.com/main.aspx?c=16056&stage=1&smonth=201808','https://www.goalzz.com/main.aspx?c=16056&stage=1&smonth=201809','https://www.goalzz.com/main.aspx?c=16056&stage=1&smonth=201810','https://www.goalzz.com/main.aspx?c=16056&stage=1&smonth=201811','https://www.goalzz.com/main.aspx?c=16056&stage=1&smonth=201812','https://www.goalzz.com/main.aspx?c=16056&stage=1&smonth=201901','https://www.goalzz.com/main.aspx?c=16056&stage=1&smonth=201902','https://www.goalzz.com/main.aspx?c=16056&stage=1&smonth=201903','https://www.goalzz.com/main.aspx?c=16056&stage=1&smonth=201904','https://www.goalzz.com/main.aspx?c=16056&stage=1&smonth=201905','https://www.goalzz.com/main.aspx?c=16056&stage=1&smonth=201906']

for j in range(0,len(links)):
    driver = webdriver.Chrome()
    driver.get(links[j])

    html = driver.page_source 
    driver.quit() 



    soup=BeautifulSoup(html)
    standing_table=soup.select('tr[data-match],td.match_date')
    date_index=[]
    for i in range(0,len(standing_table)):
        if str(standing_table[i]).startswith('<td'):
            standing_table[i]=standing_table[i].text
            date_index.append(i)

    for i in range(0,len(standing_table)):
        if i not in date_index:
            standing_table[i]=[standing_table[i].find('span').text[:5],standing_table[i].find_all('a', class_='tl')[0].text,standing_table[i].find('td', class_='sc').text,standing_table[i].find_all('a', class_='tl')[1].text,standing_table[i].find('td', class_='s').text]

    for i in range(0,len(standing_table)):
        if i in date_index:
            a=i
        if i not in date_index:
            standing_table[i].append(standing_table[a])

    for index in sorted(date_index, reverse=True):
        del standing_table[index]
    
    final_standing_table += standing_table
    
final_standing_table[:5]
# Out:
# [['17:59',
#   'Renaissance de Berkane',
#   '1 : 1',
#   'Mouloudia Oujda',
#   'Week # 1',
#   'Saturday 25 August 2018'],
#  ['20:31',
#   'Raja Club Athletic',
#   '6 : 0',
#   'Chabab Rif Al Hoceima',
#   'Week # 1',
#   'Saturday 25 August 2018'],
#  ['17:00',
#   'Youssoufia Berrechid',
#   '1 : 0',
#   'Hassania Union Sport Agadir',
#   'Week # 1',
#   'Sunday 26 August 2018'],
#  ['19:30',
#   'Olympique Club De Khouribga',
#   '2 : 1',
#   'Moghreb Tetouan',
#   'Week # 1',
#   'Sunday 26 August 2018'],
#  ['17:59',
#   'Ittihad Tanger',
#   '1 : 1',
#   'Rapide Oued Zem',
#   'Week # 1',
#   'Monday 27 August 2018']]

# %%
len(final_standing_table)
# Out:
# 241

# %%
df = pd.DataFrame(final_standing_table, columns =['Time', 'Receiving team', 'Score', 'Guest team', 'Week','Date'])
df
# Out:
#       Time               Receiving team  Score                   Guest team  \
# 0    17:59       Renaissance de Berkane  1 : 1              Mouloudia Oujda
# 1    20:31           Raja Club Athletic  6 : 0        Chabab Rif Al Hoceima
# 2    17:00         Youssoufia Berrechid  1 : 0  Hassania Union Sport Agadir
# 3    19:30  Olympique Club De Khouribga  2 : 1              Moghreb Tetouan
# 4    17:59               Ittihad Tanger  1 : 1              Rapide Oued Zem
# ..     ...                          ...    ...                          ...
# 236  19:05  Hassania Union Sport Agadir  1 : 0        Chabab Rif Al Hoceima
# 237  19:04               Ittihad Tanger  1 : 3    Fath Union Sport de Rabat
# 238  19:04         Youssoufia Berrechid  2 : 1       Olympique Club de Safi
# 239  19:00  Olympique Club De Khouribga  3 : 1              Mouloudia Oujda
# 240  19:01       Renaissance de Berkane  2 : 2              Rapide Oued Zem
#
#           Week                     Date
# 0     Week # 1  Saturday 25 August 2018
# 1     Week # 1  Saturday 25 August 2018
# 2     Week # 1    Sunday 26 August 2018
# 3     Week # 1    Sunday 26 August 2018
# 4     Week # 1    Monday 27 August 2018
# ..         ...                      ...
# 236  Week # 30       Sunday 9 June 2019
# 237  Week # 30       Sunday 9 June 2019
# 238  Week # 30       Sunday 9 June 2019
# 239  Week # 30     Tuesday 11 June 2019
# 240  Week # 30     Tuesday 11 June 2019
#
# [241 rows x 6 columns]

# %%
df.to_csv('Botola Data 2018 2019.csv')
