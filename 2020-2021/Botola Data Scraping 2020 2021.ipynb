# %%
from selenium import webdriver
from bs4 import BeautifulSoup
import pandas as pd

final_standing_table=[]
links=['https://www.goalzz.com/main.aspx?c=21404&stage=1&smonth=202012','https://www.goalzz.com/main.aspx?c=21404&stage=1&smonth=202102','https://www.goalzz.com/main.aspx?c=21404&stage=1&smonth=202103','https://www.goalzz.com/main.aspx?c=21404&stage=1&smonth=202104','https://www.goalzz.com/main.aspx?c=21404&stage=1&smonth=202105','https://www.goalzz.com/main.aspx?c=21404&stage=1&smonth=202106','https://www.goalzz.com/main.aspx?c=21404&stage=1&smonth=202107']

for j in range(0,len(links)):
    driver = webdriver.Chrome()
    driver.get(links[j])

    html = driver.page_source 
    driver.quit() 



    soup=BeautifulSoup(html)
    standing_table=soup.select('tr[data-match],td.match_date')
    date_index=[]
    for i in range(0,len(standing_table)):
        if str(standing_table[i]).startswith('<td'):
            standing_table[i]=standing_table[i].text
            date_index.append(i)

    for i in range(0,len(standing_table)):
        if i not in date_index:
            standing_table[i]=[standing_table[i].find('span').text[:5],standing_table[i].find_all('a', class_='tl')[0].text,standing_table[i].find('td', class_='sc').text,standing_table[i].find_all('a', class_='tl')[1].text,standing_table[i].find('td', class_='s').text]

    for i in range(0,len(standing_table)):
        if i in date_index:
            a=i
        if i not in date_index:
            standing_table[i].append(standing_table[a])

    for index in sorted(date_index, reverse=True):
        del standing_table[index]
    
    final_standing_table += standing_table
    
final_standing_table
# Out:
# [['17:36',
#   'Moghreb Tetouan',
#   '0 : 2',
#   'Chabab Mohammedia',
#   'Week # 1',
#   'Friday 4 December 2020'],
#  ['19:30',
#   'Maghreb de Fes',
#   '2 : 1',
#   'FAR Rabat',
#   'Week # 1',
#   'Friday 4 December 2020'],
#  ['15:32',
#   'Renaissance Zemamra',
#   '0 : 2',
#   'Renaissance de Berkane',
#   'Week # 1',
#   'Saturday 5 December 2020'],
#  ['17:34',
#   'Rapide Oued Zem',
#   '1 : 1',
#   'Mouloudia Oujda',
#   'Week # 1',
#   'Saturday 5 December 2020'],
#  ['19:32',
#   'Olympique Club de Safi',
#   '4 : 3',
#   'Difaa Hassani El Jadidi',
#   'Week # 1',
#   'Saturday 5 December 2020'],
#  ['15:36',
#   'Hassania Union Sport Agadir',
#   '0 : 1',
#   'Ittihad Tanger',
#   'Week # 1',
#   'Sunday 6 December 2020'],
#  ['17:30',
#   'Wydad Athletic Club',
#   '2 : 0',
#   'Youssoufia Berrechid',
#   'Week # 1',
#   'Sunday 6 December 2020'],
#  ['19:30',
#   'Fath Union Sport de Rabat',
#   '3 : 3',
#   'Raja Club Athletic',
#   'Week # 1',
#   'Sunday 6 December 2020'],
#  ['15:32',
#   'Renaissance de Berkane',
#   '1 : 1',
#   'Maghreb de Fes',
#   'Week # 2',
#   'Tuesday 8 December 2020'],
#  ['17:32',
#   'FAR Rabat',
#   '2 : 3',
#   'Moghreb Tetouan',
#   'Week # 2',
#   'Tuesday 8 December 2020'],
#  ['19:31',
#   'Chabab Mohammedia',
#   '1 : 0',
#   'Renaissance Zemamra',
#   'Week # 2',
#   'Tuesday 8 December 2020'],
#  ['15:29',
#   'Difaa Hassani El Jadidi',
#   '0 : 1',
#   'Wydad Athletic Club',
#   'Week # 2',
#   'Wednesday 9 December 2020'],
#  ['17:31',
#   'Youssoufia Berrechid',
#   '0 : 0',
#   'Hassania Union Sport Agadir',
#   'Week # 2',
#   'Wednesday 9 December 2020'],
#  ['19:33',
#   'Ittihad Tanger',
#   '1 : 0',
#   'Olympique Club de Safi',
#   'Week # 2',
#   'Wednesday 9 December 2020'],
#  ['17:33',
#   'Mouloudia Oujda',
#   '0 : 1',
#   'Fath Union Sport de Rabat',
#   'Week # 2',
#   'Thursday 10 December 2020'],
#  ['19:30',
#   'Raja Club Athletic',
#   '3 : 2',
#   'Rapide Oued Zem',
#   'Week # 2',
#   'Thursday 10 December 2020'],
#  ['19:30',
#   'Renaissance Zemamra',
#   '0 : 2',
#   'FAR Rabat',
#   'Week # 3',
#   'Friday 11 December 2020'],
#  ['15:32',
#   'Maghreb de Fes',
#   '1 : 1',
#   'Youssoufia Berrechid',
#   'Week # 3',
#   'Saturday 12 December 2020'],
#  ['17:30',
#   'Olympique Club de Safi',
#   '2 : 1',
#   'Wydad Athletic Club',
#   'Week # 3',
#   'Saturday 12 December 2020'],
#  ['19:33',
#   'Hassania Union Sport Agadir',
#   '0 : 0',
#   'Chabab Mohammedia',
#   'Week # 3',
#   'Saturday 12 December 2020'],
#  ['15:35',
#   'Rapide Oued Zem',
#   '1 : 3',
#   'Renaissance de Berkane',
#   'Week # 3',
#   'Sunday 13 December 2020'],
#  ['17:33',
#   'Moghreb Tetouan',
#   '2 : 2',
#   'Difaa Hassani El Jadidi',
#   'Week # 3',
#   'Sunday 13 December 2020'],
#  ['19:30',
#   'Raja Club Athletic',
#   '3 : 0',
#   'Mouloudia Oujda',
#   'Week # 3',
#   'Sunday 13 December 2020'],
#  ['19:30',
#   'Fath Union Sport de Rabat',
#   '0 : 1',
#   'Ittihad Tanger',
#   'Week # 3',
#   'Sunday 13 December 2020'],
#  ['15:30',
#   'Youssoufia Berrechid',
#   '0 : 0',
#   'Olympique Club de Safi',
#   'Week # 4',
#   'Saturday 19 December 2020'],
#  ['17:31',
#   'Wydad Athletic Club',
#   '3 : 0',
#   'Hassania Union Sport Agadir',
#   'Week # 4',
#   'Saturday 19 December 2020'],
#  ['19:30',
#   'Chabab Mohammedia',
#   '0 : 0',
#   'Rapide Oued Zem',
#   'Week # 4',
#   'Saturday 19 December 2020'],
#  ['19:30',
#   'Renaissance de Berkane',
#   '0 : 1',
#   'Raja Club Athletic',
#   'Week # 4',
#   'Saturday 19 December 2020'],
#  ['15:34',
#   'FAR Rabat',
#   '0 : 0',
#   'Fath Union Sport de Rabat',
#   'Week # 4',
#   'Sunday 20 December 2020'],
#  ['17:33',
#   'Mouloudia Oujda',
#   '1 : 2',
#   'Renaissance Zemamra',
#   'Week # 4',
#   'Sunday 20 December 2020'],
#  ['19:32',
#   'Ittihad Tanger',
#   '1 : 1',
#   'Moghreb Tetouan',
#   'Week # 4',
#   'Sunday 20 December 2020'],
#  ['19:30',
#   'Difaa Hassani El Jadidi',
#   '1 : 2',
#   'Maghreb de Fes',
#   'Week # 4',
#   'Sunday 20 December 2020'],
#  ['17:33',
#   'Moghreb Tetouan',
#   '0 : 0',
#   'Youssoufia Berrechid',
#   'Week # 5',
#   'Friday 25 December 2020'],
#  ['19:30',
#   'Fath Union Sport de Rabat',
#   '1 : 1',
#   'Difaa Hassani El Jadidi',
#   'Week # 5',
#   'Friday 25 December 2020'],
#  ['15:31',
#   'Rapide Oued Zem',
#   '0 : 0',
#   'FAR Rabat',
#   'Week # 5',
#   'Saturday 26 December 2020'],
#  ['17:34',
#   'Raja Club Athletic',
#   '1 : 0',
#   'Chabab Mohammedia',
#   'Week # 5',
#   'Saturday 26 December 2020'],
#  ['19:33',
#   'Maghreb de Fes',
#   '0 : 1',
#   'Wydad Athletic Club',
#   'Week # 5',
#   'Saturday 26 December 2020'],
#  ['15:31',
#   'Renaissance Zemamra',
#   '4 : 1',
#   'Ittihad Tanger',
#   'Week # 5',
#   'Sunday 27 December 2020'],
#  ['17:34',
#   'Hassania Union Sport Agadir',
#   '2 : 0',
#   'Olympique Club de Safi',
#   'Week # 5',
#   'Sunday 27 December 2020'],
#  ['19:32',
#   'Mouloudia Oujda',
#   '0 : 1',
#   'Renaissance de Berkane',
#   'Week # 5',
#   'Sunday 27 December 2020'],
#  ['15:00',
#   'Hassania Union Sport Agadir',
#   '1 : 1',
#   'Moghreb Tetouan',
#   'Week # 6',
#   'Saturday 13 February 2021'],
#  ['17:17',
#   'Ittihad Tanger',
#   '0 : 1',
#   'Rapide Oued Zem',
#   'Week # 6',
#   'Saturday 13 February 2021'],
#  ['19:29',
#   'Difaa Hassani El Jadidi',
#   '1 : 0',
#   'Renaissance Zemamra',
#   'Week # 6',
#   'Saturday 13 February 2021'],
#  ['15:01',
#   'Chabab Mohammedia',
#   '0 : 1',
#   'Mouloudia Oujda',
#   'Week # 6',
#   'Sunday 14 February 2021'],
#  ['17:13',
#   'Olympique Club de Safi',
#   '1 : 1',
#   'Maghreb de Fes',
#   'Week # 6',
#   'Sunday 14 February 2021'],
#  ['19:32',
#   'Youssoufia Berrechid',
#   '1 : 0',
#   'Renaissance de Berkane',
#   'Week # 6',
#   'Sunday 14 February 2021'],
#  ['19:34',
#   'Wydad Athletic Club',
#   '3 : 2',
#   'Fath Union Sport de Rabat',
#   'Week # 6',
#   'Tuesday 16 February 2021'],
#  ['19:34',
#   'FAR Rabat',
#   '1 : 1',
#   'Raja Club Athletic',
#   'Week # 6',
#   'Wednesday 17 February 2021'],
#  ['15:01',
#   'Renaissance Zemamra',
#   '1 : 2',
#   'Wydad Athletic Club',
#   'Week # 7',
#   'Friday 19 February 2021'],
#  ['15:01',
#   'Moghreb Tetouan',
#   '1 : 3',
#   'Olympique Club de Safi',
#   'Week # 7',
#   'Saturday 20 February 2021'],
#  ['17:16',
#   'Fath Union Sport de Rabat',
#   '1 : 2',
#   'Youssoufia Berrechid',
#   'Week # 7',
#   'Saturday 20 February 2021'],
#  ['19:28',
#   'Mouloudia Oujda',
#   '1 : 2',
#   'FAR Rabat',
#   'Week # 7',
#   'Saturday 20 February 2021'],
#  ['15:01',
#   'Renaissance de Berkane',
#   '1 : 1',
#   'Chabab Mohammedia',
#   'Week # 7',
#   'Sunday 21 February 2021'],
#  ['17:17',
#   'Rapide Oued Zem',
#   '0 : 2',
#   'Difaa Hassani El Jadidi',
#   'Week # 7',
#   'Sunday 21 February 2021'],
#  ['19:31',
#   'Maghreb de Fes',
#   '0 : 0',
#   'Hassania Union Sport Agadir',
#   'Week # 7',
#   'Sunday 21 February 2021'],
#  ['19:32',
#   'Raja Club Athletic',
#   '2 : 0',
#   'Ittihad Tanger',
#   'Week # 7',
#   'Thursday 25 February 2021'],
#  ['15:00',
#   'FAR Rabat',
#   '1 : 1',
#   'Chabab Mohammedia',
#   'Week # 8',
#   'Friday 26 February 2021'],
#  ['19:31',
#   'Maghreb de Fes',
#   '0 : 0',
#   'Moghreb Tetouan',
#   'Week # 8',
#   'Friday 26 February 2021'],
#  ['15:04',
#   'Hassania Union Sport Agadir',
#   '1 : 0',
#   'Renaissance Zemamra',
#   'Week # 8',
#   'Saturday 27 February 2021'],
#  ['19:30',
#   'Youssoufia Berrechid',
#   '1 : 1',
#   'Rapide Oued Zem',
#   'Week # 8',
#   'Saturday 27 February 2021'],
#  ['14:58',
#   'Olympique Club de Safi',
#   '0 : 1',
#   'Fath Union Sport de Rabat',
#   'Week # 8',
#   'Sunday 28 February 2021'],
#  ['17:17',
#   'Ittihad Tanger',
#   '1 : 2',
#   'Mouloudia Oujda',
#   'Week # 8',
#   'Sunday 28 February 2021'],
#  ['19:31',
#   'Difaa Hassani El Jadidi',
#   '0 : 0',
#   'Raja Club Athletic',
#   'Week # 8',
#   'Sunday 28 February 2021'],
#  ['17:15',
#   'Renaissance de Berkane',
#   '1 : 2',
#   'FAR Rabat',
#   'Week # 9',
#   'Saturday 6 March 2021'],
#  ['15:04',
#   'Raja Club Athletic',
#   '1 : 1',
#   'Youssoufia Berrechid',
#   'Week # 9',
#   'Sunday 7 March 2021'],
#  ['19:33',
#   'Moghreb Tetouan',
#   '2 : 2',
#   'Wydad Athletic Club',
#   'Week # 9',
#   'Thursday 11 March 2021'],
#  ['17:13',
#   'Renaissance Zemamra',
#   '1 : 2',
#   'Olympique Club de Safi',
#   'Week # 9',
#   'Saturday 13 March 2021'],
#  ['19:30',
#   'Fath Union Sport de Rabat',
#   '0 : 0',
#   'Hassania Union Sport Agadir',
#   'Week # 9',
#   'Saturday 13 March 2021'],
#  ['15:03',
#   'Mouloudia Oujda',
#   '4 : 0',
#   'Difaa Hassani El Jadidi',
#   'Week # 9',
#   'Sunday 14 March 2021'],
#  ['17:16',
#   'Chabab Mohammedia',
#   '1 : 2',
#   'Ittihad Tanger',
#   'Week # 9',
#   'Sunday 14 March 2021'],
#  ['19:30',
#   'Rapide Oued Zem',
#   '0 : 0',
#   'Maghreb de Fes',
#   'Week # 9',
#   'Sunday 14 March 2021'],
#  ['15:02',
#   'Olympique Club de Safi',
#   '0 : 0',
#   'Renaissance de Berkane',
#   'Week # 10',
#   'Sunday 21 March 2021'],
#  ['17:03',
#   'Wydad Athletic Club',
#   '2 : 0',
#   'Raja Club Athletic',
#   'Week # 10',
#   'Sunday 21 March 2021'],
#  ['17:17',
#   'Ittihad Tanger',
#   '1 : 2',
#   'FAR Rabat',
#   'Week # 10',
#   'Friday 2 April 2021'],
#  ['19:30',
#   'Hassania Union Sport Agadir',
#   '3 : 1',
#   'Rapide Oued Zem',
#   'Week # 10',
#   'Friday 2 April 2021'],
#  ['15:04',
#   'Moghreb Tetouan',
#   '3 : 0',
#   'Renaissance Zemamra',
#   'Week # 10',
#   'Saturday 3 April 2021'],
#  ['17:17',
#   'Difaa Hassani El Jadidi',
#   '0 : 0',
#   'Chabab Mohammedia',
#   'Week # 10',
#   'Saturday 3 April 2021'],
#  ['19:33',
#   'Youssoufia Berrechid',
#   '0 : 1',
#   'Mouloudia Oujda',
#   'Week # 10',
#   'Saturday 3 April 2021'],
#  ['15:05',
#   'Maghreb de Fes',
#   '1 : 1',
#   'Fath Union Sport de Rabat',
#   'Week # 10',
#   'Sunday 4 April 2021'],
#  ['15:02',
#   'Renaissance de Berkane',
#   '1 : 2',
#   'Ittihad Tanger',
#   'Week # 11',
#   'Wednesday 7 April 2021'],
#  ['17:20',
#   'Raja Club Athletic',
#   '0 : 1',
#   'Hassania Union Sport Agadir',
#   'Week # 11',
#   'Wednesday 7 April 2021'],
#  ['19:30',
#   'Rapide Oued Zem',
#   '0 : 1',
#   'Wydad Athletic Club',
#   'Week # 11',
#   'Wednesday 7 April 2021'],
#  ['19:32',
#   'FAR Rabat',
#   '1 : 0',
#   'Difaa Hassani El Jadidi',
#   'Week # 11',
#   'Friday 9 April 2021'],
#  ['15:01',
#   'Mouloudia Oujda',
#   '3 : 0',
#   'Maghreb de Fes',
#   'Week # 11',
#   'Saturday 10 April 2021'],
#  ['15:00',
#   'Renaissance Zemamra',
#   '0 : 0',
#   'Youssoufia Berrechid',
#   'Week # 11',
#   'Sunday 11 April 2021'],
#  ['17:15',
#   'Chabab Mohammedia',
#   '3 : 0',
#   'Olympique Club de Safi',
#   'Week # 11',
#   'Sunday 11 April 2021'],
#  ['19:30',
#   'Fath Union Sport de Rabat',
#   '2 : 1',
#   'Moghreb Tetouan',
#   'Week # 11',
#   'Sunday 11 April 2021'],
#  ['22:03',
#   'Wydad Athletic Club',
#   '1 : 1',
#   'Mouloudia Oujda',
#   'Week # 12',
#   'Thursday 15 April 2021'],
#  ['22:01',
#   'Hassania Union Sport Agadir',
#   '1 : 2',
#   'Renaissance de Berkane',
#   'Week # 12',
#   'Friday 16 April 2021'],
#  ['22:03',
#   'Moghreb Tetouan',
#   '2 : 3',
#   'Raja Club Athletic',
#   'Week # 12',
#   'Friday 16 April 2021'],
#  ['21:59',
#   'Olympique Club de Safi',
#   '2 : 1',
#   'Rapide Oued Zem',
#   'Week # 12',
#   'Saturday 17 April 2021'],
#  ['21:58',
#   'Fath Union Sport de Rabat',
#   '1 : 2',
#   'Renaissance Zemamra',
#   'Week # 12',
#   'Saturday 17 April 2021'],
#  ['22:02',
#   'Maghreb de Fes',
#   '1 : 1',
#   'Chabab Mohammedia',
#   'Week # 12',
#   'Sunday 18 April 2021'],
#  ['22:01',
#   'Difaa Hassani El Jadidi',
#   '0 : 0',
#   'Ittihad Tanger',
#   'Week # 12',
#   'Sunday 18 April 2021'],
#  ['22:03',
#   'Youssoufia Berrechid',
#   '1 : 1',
#   'FAR Rabat',
#   'Week # 12',
#   'Sunday 18 April 2021'],
#  ['22:05',
#   'FAR Rabat',
#   '0 : 2',
#   'Hassania Union Sport Agadir',
#   'Week # 13',
#   'Friday 23 April 2021'],
#  ['22:02',
#   'Renaissance Zemamra',
#   '1 : 1',
#   'Maghreb de Fes',
#   'Week # 13',
#   'Friday 23 April 2021'],
#  ['22:01',
#   'Chabab Mohammedia',
#   '0 : 1',
#   'Youssoufia Berrechid',
#   'Week # 13',
#   'Saturday 24 April 2021'],
#  ['22:01',
#   'Mouloudia Oujda',
#   '1 : 2',
#   'Moghreb Tetouan',
#   'Week # 13',
#   'Saturday 24 April 2021'],
#  ['22:00',
#   'Rapide Oued Zem',
#   '2 : 1',
#   'Fath Union Sport de Rabat',
#   'Week # 13',
#   'Saturday 24 April 2021'],
#  ['22:01',
#   'Raja Club Athletic',
#   '2 : 0',
#   'Olympique Club de Safi',
#   'Week # 13',
#   'Sunday 25 April 2021'],
#  ['22:04',
#   'Ittihad Tanger',
#   '3 : 2',
#   'Wydad Athletic Club',
#   'Week # 13',
#   'Sunday 25 April 2021'],
#  ['22:02',
#   'Renaissance de Berkane',
#   '2 : 0',
#   'Difaa Hassani El Jadidi',
#   'Week # 13',
#   'Sunday 25 April 2021'],
#  ['22:00',
#   'Wydad Athletic Club',
#   '1 : 1',
#   'Chabab Mohammedia',
#   'Week # 14',
#   'Thursday 29 April 2021'],
#  ['22:00',
#   'Hassania Union Sport Agadir',
#   '1 : 0',
#   'Mouloudia Oujda',
#   'Week # 14',
#   'Friday 30 April 2021'],
#  ['22:02',
#   'Maghreb de Fes',
#   '2 : 1',
#   'Ittihad Tanger',
#   'Week # 14',
#   'Saturday 1 May 2021'],
#  ['22:01',
#   'Olympique Club de Safi',
#   '0 : 3',
#   'FAR Rabat',
#   'Week # 14',
#   'Saturday 1 May 2021'],
#  ['22:00',
#   'Youssoufia Berrechid',
#   '0 : 1',
#   'Difaa Hassani El Jadidi',
#   'Week # 14',
#   'Saturday 1 May 2021'],
#  ['22:00',
#   'Wydad Athletic Club',
#   '4 : 0',
#   'Renaissance de Berkane',
#   'Week # 8',
#   'Sunday 2 May 2021'],
#  ['22:02',
#   'Moghreb Tetouan',
#   '1 : 1',
#   'Rapide Oued Zem',
#   'Week # 14',
#   'Sunday 2 May 2021'],
#  ['22:01',
#   'Renaissance Zemamra',
#   '1 : 1',
#   'Raja Club Athletic',
#   'Week # 14',
#   'Sunday 2 May 2021'],
#  ['22:02',
#   'Fath Union Sport de Rabat',
#   '3 : 1',
#   'Renaissance de Berkane',
#   'Week # 14',
#   'Wednesday 5 May 2021'],
#  ['22:07',
#   'Ittihad Tanger',
#   '2 : 0',
#   'Youssoufia Berrechid',
#   'Week # 15',
#   'Friday 7 May 2021'],
#  ['22:00',
#   'Chabab Mohammedia',
#   '0 : 0',
#   'Fath Union Sport de Rabat',
#   'Week # 15',
#   'Saturday 8 May 2021'],
#  ['22:01',
#   'Mouloudia Oujda',
#   '3 : 2',
#   'Olympique Club de Safi',
#   'Week # 15',
#   'Saturday 8 May 2021'],
#  ['22:01',
#   'Difaa Hassani El Jadidi',
#   '1 : 0',
#   'Hassania Union Sport Agadir',
#   'Week # 15',
#   'Saturday 8 May 2021'],
#  ['22:01',
#   'Rapide Oued Zem',
#   '3 : 2',
#   'Renaissance Zemamra',
#   'Week # 15',
#   'Saturday 8 May 2021'],
#  ['22:00',
#   'Raja Club Athletic',
#   '1 : 0',
#   'Maghreb de Fes',
#   'Week # 15',
#   'Sunday 9 May 2021'],
#  ['22:00',
#   'FAR Rabat',
#   '0 : 0',
#   'Wydad Athletic Club',
#   'Week # 15',
#   'Sunday 9 May 2021'],
#  ['21:59',
#   'Renaissance de Berkane',
#   '1 : 1',
#   'Moghreb Tetouan',
#   'Week # 15',
#   'Sunday 9 May 2021'],
#  ['22:01',
#   'Ittihad Tanger',
#   '1 : 1',
#   'Hassania Union Sport Agadir',
#   'Week # 16',
#   'Tuesday 11 May 2021'],
#  ['22:01',
#   'Mouloudia Oujda',
#   '0 : 0',
#   'Rapide Oued Zem',
#   'Week # 16',
#   'Tuesday 11 May 2021'],
#  ['21:58',
#   'Difaa Hassani El Jadidi',
#   '0 : 1',
#   'Olympique Club de Safi',
#   'Week # 16',
#   'Tuesday 11 May 2021'],
#  ['22:04',
#   'Raja Club Athletic',
#   '1 : 1',
#   'Fath Union Sport de Rabat',
#   'Week # 16',
#   'Wednesday 12 May 2021'],
#  ['22:02',
#   'Chabab Mohammedia',
#   '0 : 0',
#   'Moghreb Tetouan',
#   'Week # 16',
#   'Wednesday 12 May 2021'],
#  ['22:02',
#   'FAR Rabat',
#   '3 : 2',
#   'Maghreb de Fes',
#   'Week # 16',
#   'Wednesday 12 May 2021'],
#  ['22:01',
#   'Renaissance de Berkane',
#   '2 : 0',
#   'Renaissance Zemamra',
#   'Week # 16',
#   'Wednesday 12 May 2021'],
#  ['17:00',
#   'Olympique Club de Safi',
#   '1 : 1',
#   'Ittihad Tanger',
#   'Week # 17',
#   'Saturday 15 May 2021'],
#  ['17:02',
#   'Renaissance Zemamra',
#   '1 : 1',
#   'Chabab Mohammedia',
#   'Week # 17',
#   'Saturday 15 May 2021'],
#  ['19:15',
#   'Moghreb Tetouan',
#   '0 : 0',
#   'FAR Rabat',
#   'Week # 17',
#   'Saturday 15 May 2021'],
#  ['17:06',
#   'Fath Union Sport de Rabat',
#   '0 : 3',
#   'Mouloudia Oujda',
#   'Week # 17',
#   'Sunday 16 May 2021'],
#  ['19:22',
#   'Maghreb de Fes',
#   '2 : 0',
#   'Renaissance de Berkane',
#   'Week # 17',
#   'Sunday 16 May 2021'],
#  ['21:33',
#   'Hassania Union Sport Agadir',
#   '2 : 1',
#   'Youssoufia Berrechid',
#   'Week # 17',
#   'Sunday 16 May 2021'],
#  ['19:17',
#   'Difaa Hassani El Jadidi',
#   '2 : 2',
#   'Moghreb Tetouan',
#   'Week # 18',
#   'Tuesday 18 May 2021'],
#  ['21:55',
#   'Wydad Athletic Club',
#   '3 : 1',
#   'Olympique Club de Safi',
#   'Week # 18',
#   'Tuesday 18 May 2021'],
#  ['17:04',
#   'Youssoufia Berrechid',
#   '1 : 1',
#   'Maghreb de Fes',
#   'Week # 18',
#   'Wednesday 19 May 2021'],
#  ['19:15',
#   'Chabab Mohammedia',
#   '0 : 0',
#   'Hassania Union Sport Agadir',
#   'Week # 18',
#   'Wednesday 19 May 2021'],
#  ['21:30',
#   'Renaissance de Berkane',
#   '0 : 0',
#   'Rapide Oued Zem',
#   'Week # 18',
#   'Wednesday 19 May 2021'],
#  ['17:04',
#   'Ittihad Tanger',
#   '1 : 2',
#   'Fath Union Sport de Rabat',
#   'Week # 18',
#   'Thursday 20 May 2021'],
#  ['19:19',
#   'Mouloudia Oujda',
#   '0 : 2',
#   'Raja Club Athletic',
#   'Week # 18',
#   'Thursday 20 May 2021'],
#  ['21:32',
#   'FAR Rabat',
#   '2 : 1',
#   'Renaissance Zemamra',
#   'Week # 18',
#   'Thursday 20 May 2021'],
#  ['17:02',
#   'Maghreb de Fes',
#   '1 : 3',
#   'Difaa Hassani El Jadidi',
#   'Week # 19',
#   'Saturday 22 May 2021'],
#  ['19:23',
#   'Rapide Oued Zem',
#   '3 : 2',
#   'Chabab Mohammedia',
#   'Week # 19',
#   'Saturday 22 May 2021'],
#  ['21:30',
#   'Olympique Club de Safi',
#   '1 : 1',
#   'Youssoufia Berrechid',
#   'Week # 19',
#   'Saturday 22 May 2021'],
#  ['16:59',
#   'Fath Union Sport de Rabat',
#   '2 : 1',
#   'FAR Rabat',
#   'Week # 19',
#   'Sunday 23 May 2021'],
#  ['19:17',
#   'Renaissance Zemamra',
#   '3 : 4',
#   'Mouloudia Oujda',
#   'Week # 19',
#   'Sunday 23 May 2021'],
#  ['21:34',
#   'Moghreb Tetouan',
#   '1 : 0',
#   'Ittihad Tanger',
#   'Week # 19',
#   'Sunday 23 May 2021'],
#  ['21:30',
#   'Olympique Club de Safi',
#   '1 : 0',
#   'Hassania Union Sport Agadir',
#   'Week # 20',
#   'Tuesday 25 May 2021'],
#  ['17:00',
#   'Wydad Athletic Club',
#   '2 : 0',
#   'Maghreb de Fes',
#   'Week # 20',
#   'Wednesday 26 May 2021'],
#  ['19:17',
#   'Ittihad Tanger',
#   '2 : 0',
#   'Renaissance Zemamra',
#   'Week # 20',
#   'Wednesday 26 May 2021'],
#  ['21:34',
#   'FAR Rabat',
#   '1 : 1',
#   'Rapide Oued Zem',
#   'Week # 20',
#   'Wednesday 26 May 2021'],
#  ['21:31',
#   'Difaa Hassani El Jadidi',
#   '3 : 1',
#   'Fath Union Sport de Rabat',
#   'Week # 20',
#   'Wednesday 26 May 2021'],
#  ['19:16',
#   'Youssoufia Berrechid',
#   '0 : 3',
#   'Moghreb Tetouan',
#   'Week # 20',
#   'Thursday 27 May 2021'],
#  ['21:30',
#   'Chabab Mohammedia',
#   '1 : 2',
#   'Raja Club Athletic',
#   'Week # 20',
#   'Thursday 27 May 2021'],
#  ['17:02',
#   'Renaissance Zemamra',
#   '1 : 0',
#   'Difaa Hassani El Jadidi',
#   'Week # 21',
#   'Saturday 29 May 2021'],
#  ['19:16',
#   'Maghreb de Fes',
#   '1 : 2',
#   'Olympique Club de Safi',
#   'Week # 21',
#   'Saturday 29 May 2021'],
#  ['21:30',
#   'Rapide Oued Zem',
#   '1 : 2',
#   'Ittihad Tanger',
#   'Week # 21',
#   'Saturday 29 May 2021'],
#  ['17:04',
#   'Mouloudia Oujda',
#   '3 : 2',
#   'Chabab Mohammedia',
#   'Week # 21',
#   'Sunday 30 May 2021'],
#  ['19:17',
#   'Fath Union Sport de Rabat',
#   '0 : 0',
#   'Wydad Athletic Club',
#   'Week # 21',
#   'Sunday 30 May 2021'],
#  ['21:30',
#   'Raja Club Athletic',
#   '3 : 2',
#   'FAR Rabat',
#   'Week # 21',
#   'Sunday 30 May 2021'],
#  ['21:33',
#   'Moghreb Tetouan',
#   '2 : 1',
#   'Hassania Union Sport Agadir',
#   'Week # 21',
#   'Sunday 30 May 2021'],
#  ['17:00',
#   'Rapide Oued Zem',
#   '0 : 2',
#   'Raja Club Athletic',
#   'Week # 17',
#   'Thursday 3 June 2021'],
#  ['19:15',
#   'Renaissance de Berkane',
#   '3 : 1',
#   'Mouloudia Oujda',
#   'Week # 20',
#   'Thursday 3 June 2021'],
#  ['21:30',
#   'Youssoufia Berrechid',
#   '0 : 1',
#   'Wydad Athletic Club',
#   'Week # 16',
#   'Thursday 3 June 2021'],
#  ['17:03',
#   'Wydad Athletic Club',
#   '4 : 2',
#   'Difaa Hassani El Jadidi',
#   'Week # 17',
#   'Wednesday 9 June 2021'],
#  ['19:16',
#   'Renaissance de Berkane',
#   '1 : 1',
#   'Youssoufia Berrechid',
#   'Week # 21',
#   'Wednesday 9 June 2021'],
#  ['19:15',
#   'Hassania Union Sport Agadir',
#   '3 : 5',
#   'Wydad Athletic Club',
#   'Week # 19',
#   'Sunday 13 June 2021'],
#  ['21:30',
#   'Raja Club Athletic',
#   '0 : 1',
#   'Renaissance de Berkane',
#   'Week # 19',
#   'Sunday 13 June 2021'],
#  ['19:18',
#   'Wydad Athletic Club',
#   '0 : 0',
#   'Renaissance Zemamra',
#   'Week # 22',
#   'Wednesday 16 June 2021'],
#  ['21:31',
#   'Ittihad Tanger',
#   '0 : 3',
#   'Raja Club Athletic',
#   'Week # 22',
#   'Wednesday 16 June 2021'],
#  ['17:01',
#   'FAR Rabat',
#   '1 : 0',
#   'Mouloudia Oujda',
#   'Week # 22',
#   'Saturday 19 June 2021'],
#  ['19:16',
#   'Olympique Club de Safi',
#   '0 : 0',
#   'Moghreb Tetouan',
#   'Week # 22',
#   'Saturday 19 June 2021'],
#  ['21:31',
#   'Chabab Mohammedia',
#   '2 : 0',
#   'Renaissance de Berkane',
#   'Week # 22',
#   'Saturday 19 June 2021'],
#  ['16:59',
#   'Difaa Hassani El Jadidi',
#   '1 : 1',
#   'Rapide Oued Zem',
#   'Week # 22',
#   'Sunday 20 June 2021'],
#  ['19:15',
#   'Youssoufia Berrechid',
#   '2 : 1',
#   'Fath Union Sport de Rabat',
#   'Week # 22',
#   'Sunday 20 June 2021'],
#  ['21:33',
#   'Hassania Union Sport Agadir',
#   '1 : 1',
#   'Maghreb de Fes',
#   'Week # 22',
#   'Sunday 20 June 2021'],
#  ['21:30',
#   'Renaissance de Berkane',
#   '0 : 2',
#   'Wydad Athletic Club',
#   'Week # 23',
#   'Tuesday 22 June 2021'],
#  ['19:17',
#   'Raja Club Athletic',
#   '2 : 0',
#   'Difaa Hassani El Jadidi',
#   'Week # 23',
#   'Thursday 24 June 2021'],
#  ['17:02',
#   'Moghreb Tetouan',
#   '0 : 0',
#   'Maghreb de Fes',
#   'Week # 23',
#   'Saturday 26 June 2021'],
#  ['19:16',
#   'Mouloudia Oujda',
#   '0 : 0',
#   'Ittihad Tanger',
#   'Week # 23',
#   'Saturday 26 June 2021'],
#  ['21:31',
#   'Rapide Oued Zem',
#   '2 : 0',
#   'Youssoufia Berrechid',
#   'Week # 23',
#   'Saturday 26 June 2021'],
#  ['17:01',
#   'Renaissance Zemamra',
#   '1 : 0',
#   'Hassania Union Sport Agadir',
#   'Week # 23',
#   'Sunday 27 June 2021'],
#  ['19:17',
#   'Chabab Mohammedia',
#   '0 : 2',
#   'FAR Rabat',
#   'Week # 23',
#   'Sunday 27 June 2021'],
#  ['21:34',
#   'Fath Union Sport de Rabat',
#   '2 : 1',
#   'Olympique Club de Safi',
#   'Week # 23',
#   'Sunday 27 June 2021'],
#  ['19:18',
#   'Difaa Hassani El Jadidi',
#   '2 : 2',
#   'Mouloudia Oujda',
#   'Week # 24',
#   'Tuesday 29 June 2021'],
#  ['21:33',
#   'Maghreb de Fes',
#   '2 : 1',
#   'Rapide Oued Zem',
#   'Week # 24',
#   'Tuesday 29 June 2021'],
#  ['17:04',
#   'Hassania Union Sport Agadir',
#   '0 : 0',
#   'Fath Union Sport de Rabat',
#   'Week # 24',
#   'Wednesday 30 June 2021'],
#  ['19:16',
#   'Wydad Athletic Club',
#   '4 : 2',
#   'Moghreb Tetouan',
#   'Week # 24',
#   'Wednesday 30 June 2021'],
#  ['21:30',
#   'Youssoufia Berrechid',
#   '1 : 0',
#   'Raja Club Athletic',
#   'Week # 24',
#   'Wednesday 30 June 2021'],
#  ['17:01',
#   'FAR Rabat',
#   '3 : 1',
#   'Renaissance de Berkane',
#   'Week # 24',
#   'Thursday 1 July 2021'],
#  ['19:19',
#   'Ittihad Tanger',
#   '0 : 1',
#   'Chabab Mohammedia',
#   'Week # 24',
#   'Thursday 1 July 2021'],
#  ['21:33',
#   'Olympique Club de Safi',
#   '2 : 2',
#   'Renaissance Zemamra',
#   'Week # 24',
#   'Thursday 1 July 2021'],
#  ['17:03',
#   'Fath Union Sport de Rabat',
#   '0 : 1',
#   'Maghreb de Fes',
#   'Week # 25',
#   'Saturday 3 July 2021'],
#  ['19:16',
#   'Mouloudia Oujda',
#   '3 : 1',
#   'Youssoufia Berrechid',
#   'Week # 25',
#   'Saturday 3 July 2021'],
#  ['19:18',
#   'Rapide Oued Zem',
#   '0 : 1',
#   'Hassania Union Sport Agadir',
#   'Week # 25',
#   'Saturday 3 July 2021'],
#  ['21:31',
#   'Raja Club Athletic',
#   '1 : 2',
#   'Wydad Athletic Club',
#   'Week # 25',
#   'Saturday 3 July 2021'],
#  ['17:00',
#   'FAR Rabat',
#   '2 : 1',
#   'Ittihad Tanger',
#   'Week # 25',
#   'Sunday 4 July 2021'],
#  ['17:02',
#   'Renaissance Zemamra',
#   '3 : 0',
#   'Moghreb Tetouan',
#   'Week # 25',
#   'Sunday 4 July 2021'],
#  ['19:16',
#   'Chabab Mohammedia',
#   '2 : 0',
#   'Difaa Hassani El Jadidi',
#   'Week # 25',
#   'Sunday 4 July 2021'],
#  ['21:32',
#   'Renaissance de Berkane',
#   '3 : 0',
#   'Olympique Club de Safi',
#   'Week # 25',
#   'Sunday 4 July 2021'],
#  ['17:03',
#   'Hassania Union Sport Agadir',
#   '0 : 0',
#   'Raja Club Athletic',
#   'Week # 26',
#   'Tuesday 6 July 2021'],
#  ['19:20',
#   'Maghreb de Fes',
#   '2 : 1',
#   'Mouloudia Oujda',
#   'Week # 26',
#   'Tuesday 6 July 2021'],
#  ['17:01',
#   'Youssoufia Berrechid',
#   '1 : 1',
#   'Renaissance Zemamra',
#   'Week # 26',
#   'Wednesday 7 July 2021'],
#  ['19:15',
#   'Olympique Club de Safi',
#   '1 : 1',
#   'Chabab Mohammedia',
#   'Week # 26',
#   'Wednesday 7 July 2021'],
#  ['21:32',
#   'Wydad Athletic Club',
#   '2 : 0',
#   'Rapide Oued Zem',
#   'Week # 26',
#   'Wednesday 7 July 2021'],
#  ['17:02',
#   'Moghreb Tetouan',
#   '2 : 2',
#   'Fath Union Sport de Rabat',
#   'Week # 26',
#   'Thursday 8 July 2021'],
#  ['19:16',
#   'Difaa Hassani El Jadidi',
#   '1 : 0',
#   'FAR Rabat',
#   'Week # 26',
#   'Thursday 8 July 2021'],
#  ['21:33',
#   'Ittihad Tanger',
#   '0 : 2',
#   'Renaissance de Berkane',
#   'Week # 26',
#   'Thursday 8 July 2021'],
#  ['17:03',
#   'FAR Rabat',
#   '3 : 2',
#   'Youssoufia Berrechid',
#   'Week # 27',
#   'Tuesday 13 July 2021'],
#  ['17:01',
#   'Renaissance Zemamra',
#   '1 : 0',
#   'Fath Union Sport de Rabat',
#   'Week # 27',
#   'Tuesday 13 July 2021'],
#  ['19:16',
#   'Renaissance de Berkane',
#   '1 : 0',
#   'Hassania Union Sport Agadir',
#   'Week # 27',
#   'Tuesday 13 July 2021'],
#  ['21:33',
#   'Rapide Oued Zem',
#   '2 : 1',
#   'Olympique Club de Safi',
#   'Week # 27',
#   'Tuesday 13 July 2021'],
#  ['17:02',
#   'Raja Club Athletic',
#   '4 : 1',
#   'Moghreb Tetouan',
#   'Week # 27',
#   'Wednesday 14 July 2021'],
#  ['19:18',
#   'Ittihad Tanger',
#   '0 : 1',
#   'Difaa Hassani El Jadidi',
#   'Week # 27',
#   'Wednesday 14 July 2021'],
#  ['21:30',
#   'Chabab Mohammedia',
#   '1 : 1',
#   'Maghreb de Fes',
#   'Week # 27',
#   'Wednesday 14 July 2021'],
#  ['21:32',
#   'Mouloudia Oujda',
#   '0 : 2',
#   'Wydad Athletic Club',
#   'Week # 27',
#   'Wednesday 14 July 2021'],
#  ['17:01',
#   'Olympique Club de Safi',
#   '2 : 2',
#   'Raja Club Athletic',
#   'Week # 28',
#   'Saturday 17 July 2021'],
#  ['19:18',
#   'Hassania Union Sport Agadir',
#   '0 : 1',
#   'FAR Rabat',
#   'Week # 28',
#   'Saturday 17 July 2021'],
#  ['21:33',
#   'Moghreb Tetouan',
#   '0 : 1',
#   'Mouloudia Oujda',
#   'Week # 28',
#   'Saturday 17 July 2021'],
#  ['17:02',
#   'Wydad Athletic Club',
#   '2 : 4',
#   'Ittihad Tanger',
#   'Week # 28',
#   'Sunday 18 July 2021'],
#  ['19:31',
#   'Maghreb de Fes',
#   '2 : 2',
#   'Renaissance Zemamra',
#   'Week # 28',
#   'Sunday 18 July 2021'],
#  ['19:32',
#   'Difaa Hassani El Jadidi',
#   '3 : 1',
#   'Renaissance de Berkane',
#   'Week # 28',
#   'Sunday 18 July 2021'],
#  ['19:31',
#   'Youssoufia Berrechid',
#   '0 : 1',
#   'Chabab Mohammedia',
#   'Week # 28',
#   'Sunday 18 July 2021'],
#  ['19:30',
#   'Fath Union Sport de Rabat',
#   '0 : 0',
#   'Rapide Oued Zem',
#   'Week # 28',
#   'Sunday 18 July 2021'],
#  ['19:31',
#   'Raja Club Athletic',
#   '1 : 0',
#   'Renaissance Zemamra',
#   'Week # 29',
#   'Friday 23 July 2021'],
#  ['19:31',
#   'Difaa Hassani El Jadidi',
#   '2 : 3',
#   'Youssoufia Berrechid',
#   'Week # 29',
#   'Friday 23 July 2021'],
#  ['19:31',
#   'Renaissance de Berkane',
#   '3 : 2',
#   'Fath Union Sport de Rabat',
#   'Week # 29',
#   'Friday 23 July 2021'],
#  ['19:33',
#   'Rapide Oued Zem',
#   '2 : 1',
#   'Moghreb Tetouan',
#   'Week # 29',
#   'Friday 23 July 2021'],
#  ['17:01',
#   'FAR Rabat',
#   '0 : 0',
#   'Olympique Club de Safi',
#   'Week # 29',
#   'Saturday 24 July 2021'],
#  ['19:16',
#   'Chabab Mohammedia',
#   '1 : 1',
#   'Wydad Athletic Club',
#   'Week # 29',
#   'Saturday 24 July 2021'],
#  ['21:32',
#   'Ittihad Tanger',
#   '0 : 0',
#   'Maghreb de Fes',
#   'Week # 29',
#   'Saturday 24 July 2021'],
#  ['21:31',
#   'Mouloudia Oujda',
#   '1 : 0',
#   'Hassania Union Sport Agadir',
#   'Week # 29',
#   'Saturday 24 July 2021'],
#  ['19:31',
#   'Moghreb Tetouan',
#   '2 : 3',
#   'Renaissance de Berkane',
#   'Week # 30',
#   'Tuesday 27 July 2021'],
#  ['19:31',
#   'Youssoufia Berrechid',
#   '1 : 0',
#   'Ittihad Tanger',
#   'Week # 30',
#   'Tuesday 27 July 2021'],
#  ['19:31',
#   'Fath Union Sport de Rabat',
#   '2 : 0',
#   'Chabab Mohammedia',
#   'Week # 30',
#   'Tuesday 27 July 2021'],
#  ['19:31',
#   'Renaissance Zemamra',
#   '1 : 1',
#   'Rapide Oued Zem',
#   'Week # 30',
#   'Tuesday 27 July 2021'],
#  ['19:00',
#   'Wydad Athletic Club',
#   '2 : 0',
#   'FAR Rabat',
#   'Week # 30',
#   'Wednesday 28 July 2021'],
#  ['18:59',
#   'Maghreb de Fes',
#   '2 : 3',
#   'Raja Club Athletic',
#   'Week # 30',
#   'Wednesday 28 July 2021'],
#  ['21:30',
#   'Hassania Union Sport Agadir',
#   '2 : 0',
#   'Difaa Hassani El Jadidi',
#   'Week # 30',
#   'Wednesday 28 July 2021'],
#  ['21:30',
#   'Olympique Club de Safi',
#   '0 : 0',
#   'Mouloudia Oujda',
#   'Week # 30',
#   'Wednesday 28 July 2021']]

# %%
len(final_standing_table)
# Out:
# 240

# %%
df = pd.DataFrame(final_standing_table, columns =['Time', 'Receiving team', 'Score', 'Guest team', 'Week','Date'])
df
# Out:
#       Time               Receiving team  Score               Guest team  \
# 0    17:36              Moghreb Tetouan  0 : 2        Chabab Mohammedia
# 1    19:30               Maghreb de Fes  2 : 1                FAR Rabat
# 2    15:32          Renaissance Zemamra  0 : 2   Renaissance de Berkane
# 3    17:34              Rapide Oued Zem  1 : 1          Mouloudia Oujda
# 4    19:32       Olympique Club de Safi  4 : 3  Difaa Hassani El Jadidi
# ..     ...                          ...    ...                      ...
# 235  19:31          Renaissance Zemamra  1 : 1          Rapide Oued Zem
# 236  19:00          Wydad Athletic Club  2 : 0                FAR Rabat
# 237  18:59               Maghreb de Fes  2 : 3       Raja Club Athletic
# 238  21:30  Hassania Union Sport Agadir  2 : 0  Difaa Hassani El Jadidi
# 239  21:30       Olympique Club de Safi  0 : 0          Mouloudia Oujda
#
#           Week                      Date
# 0     Week # 1    Friday 4 December 2020
# 1     Week # 1    Friday 4 December 2020
# 2     Week # 1  Saturday 5 December 2020
# 3     Week # 1  Saturday 5 December 2020
# 4     Week # 1  Saturday 5 December 2020
# ..         ...                       ...
# 235  Week # 30      Tuesday 27 July 2021
# 236  Week # 30    Wednesday 28 July 2021
# 237  Week # 30    Wednesday 28 July 2021
# 238  Week # 30    Wednesday 28 July 2021
# 239  Week # 30    Wednesday 28 July 2021
#
# [240 rows x 6 columns]

# %%
df.to_csv('Botola Data 2020 2021.csv')
